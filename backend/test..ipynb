# %%
import streamlit as st 

st.title("Intelligent Hotel Revenue Management System")
# Out:
# 2026-02-17 18:25:07.892 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-17 18:25:08.313
# ...
#   command:
#
#     streamlit run c:\Users\amrit\hotelRevnue\venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-02-17 18:25:08.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-17 18:25:08.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
